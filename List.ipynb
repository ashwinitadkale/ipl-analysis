# %% [markdown]
# <a href="https://colab.research.google.com/github/ashwinitadkale/ipl-analysis/blob/main/List.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ###`Problem 1:` Combine two lists index-wise(columns wise)
#
# Write a program to add two lists index-wise. Create a new list that contains the 0th index item from both the list, then the 1st index item, and so on till the last element. any leftover items will get added at the end of the new list.
#
# `Given List:`
# ```
# list1 = ["M", "na", "i", "Kh"]
# list2 = ["y", "me", "s", "an"]
# ```
#
# `Output:`
# ```
# [['M','y'], ['na', me'], ['i', 's'], ['Kh', 'an']]
# ```

# %%
list1 = ["M", "na", "i", "Kh"]
list2 = ["y", "me", "s", "an"]
res=[]
for i in range(max(len(list1),len(list2))):
  res.append(list([list1[i],list2[i]]))
print(res)
# Out:
# [['M', 'y'], ['na', 'me'], ['i', 's'], ['Kh', 'an']]

# %% [markdown]
# ### `Problem 2:` Add new item to list after a specified item
# Write a program to add item 7000 after 6000 in the following Python List
# ```
# list1 = [10, 20, [300, 400, [5000, 6000], 500], 30, 40]
# ```
# `Output:`
# ```
# [10, 20, [300, 400, [5000, 6000, 7000], 500], 30, 40]
# ```

# %%
list1 = [10, 20, [300, 400, [5000, 6000], 500], 30, 40]
list1[2][2].append(7000)
print(list1)
# Out:
# [10, 20, [300, 400, [5000, 6000, 7000], 500], 30, 40]

# %% [markdown]
# ###`Problem 3:` Update no of items available
#
# Suppose you are given a list of candy and another list of same size representing no of items of respective candy.
#
# i.e -
# ```
# candy_list = ['Jelly Belly','Kit Kat','Double Bubble','Milky Way','Three Musketeers']
# no_of_items = [10,20,34,74,32]
# ```
#
# Write a program to show no. of items of each candy type.
#
# `Output:`
#
# ```
# Jelly Belly-10
# Kit Kat-20
# Double Bubble-34
# Milky Way-74
# Three Musketeers-32
#
# ```

# %%
candy_list = ['Jelly Belly','Kit Kat','Double Bubble','Milky Way','Three Musketeers']
no_of_items = [10,20,34,74,32]
for candy,count in zip(candy_list,no_of_items):
  print(f"{candy}--{count}")
# Out:
# Jelly Belly--10
# Kit Kat--20
# Double Bubble--34
# Milky Way--74
# Three Musketeers--32

# %% [markdown]
# ###`Problem 4:` Running Sum on list
# Write a program to print a list after performing running sum on it.
#
# i.e:
#
# `Input:`
# ```
# list1 = [1,2,3,4,5,6]
# ```
# `Output:`
# ```
# [1,3,6,10,15,21]
# ```

# %%
list1 = [1,2,3,4,5,6]
result=[]
res=0
for i in range(len(list1)):
  res+=list1[i]
  result.append(res)
print(result)
# Out:
# [1, 3, 6, 10, 15, 21]

# %% [markdown]
# ###`Problem 5:` You are given a list of integers. You are asked to make a list by running through elements of the list by adding all elements greater and itself.
#
# i.e. Say given list is `[2,4,6,10,1]`
# resultant list will be `[22,20,10,23]`.
#
# For 1st element `2` ->> these are greater `(4+6+10)` values and `2` itself so on adding becomes `22`.
#
# For 2nd element `4` ->> greater elements are `(6, 10)` and `4` itself, so on adding `20`
#
# like wise for all other elememts.
#
# `[2,4,6,10,1]`-->`[22,20,16,10,23]`

# %%
list1=[2,4,6,10,1]
result=[]
for i in range(len(list1)):
  res=list1[i]
  for j in range(len(list1)):
    if list1[j]>list1[i]:
      res+=list1[j]
  result.append(res)
print(result)
# Out:
# [22, 20, 16, 10, 23]

# %% [markdown]
# ###`Problem 6:` Find list of common unique items from two list. and show in increasing order
#
# `Input`
#
# ```
# num1 = [23,45,67,78,89,34]
# num2 = [34,89,55,56,39,67]
# ```
#
# `Output:`
# ```
# [34, 67, 89]
# ```

# %%
num1 = [23,45,67,78,89,34]
num2 = [34,89,55,56,39,67]
res=[]
for n1 in num1:
  if n1 in num2 and n1 not in res:
    res.append(n1)
res.sort()
print(res)
#Better approach
num1 = [23,45,67,78,89,34]
num2 = [34,89,55,56,39,67]

res = sorted(list(set(num1) & set(num2)))

print(res)
# Out:
# [34, 67, 89]
# [34, 67, 89]

# %% [markdown]
# ###`Problem 7:` Sort a list of alphanumeric strings based on product value of numeric character in it. If in any string there is no numeric character take it's product value as 1.
#
# `Input:`
# ```
# ['1ac21', '23fg', '456', '098d','1','kls']
# ```
#
# `Output:`
# ```
# ['456', '23fg', '1ac21', '1', 'kls', '098d']
#
# ```

# %%
lst = ['1ac21', '23fg', '456', '098d','1','kls']

def product_of_digits(s):
    prod = 1
    has_digit = False

    for ch in s:
        if ch.isdigit():
            prod *= int(ch)
            has_digit = True

    return prod if has_digit else 1

# Sort based on product
result = sorted(lst, key=product_of_digits)

print(result)
# Out:
# ['098d', '1', 'kls', '1ac21', '23fg', '456']

# %% [markdown]
# `Problem 8:` Split String of list on K character.
#
# **Example :**
#
# Input:
# ```bash
# ['Ashwini is a student', 'of data-science', 'ML aspirant.']
# ```
#
# Output:
# ```bash
# ['Ashwini', 'is', 'a', 'channel', 'of', 'data-science', 'ML','aspirant.']
# ```

# %%
l1=['Ashwini is a student', 'of data-science', 'ML aspirant.']
# res=[]
# for item in l1:
#   words=item.split()
#   res.extend(words)
# print(res)
res="".join(l1).split()
print(res)
# Out:
# ['Ashwini', 'is', 'a', 'studentof', 'data-scienceML', 'aspirant.']

# %% [markdown]
# ### `Problem 9:` Convert Character Matrix to single String using string comprehension.
#
# **Example 1:**
#
# Input:
# ```bash
# [['a','s','h','w','i','n','i'], ['i', 's'], ['d','s'], ['s','t','u','d','e','n','t']]
# ```
#
# Output:
# ```bash
# ashwini is ds student
# ```

# %%
matrix=[['a','s','h','w','i','n','i'], ['i', 's'], ['d','s'], ['s','t','u','d','e','n','t']]
res=" ".join(["".join(word) for word in matrix])
print(res)
# Out:
# ashwini is ds student

# %% [markdown]
# ### `Problem 10:` Add Space between Potential Words.
#
# **Example:**
#
# Input:
#
# ```bash
# ['MLIs', 'bestFor', 'dataScientist']
# ```
#
# Output:
# ```bash
# ['ML Is', 'best For', 'data Scientist']
# ```

# %%
lst = ['MLIs', 'bestFor', 'dataScientist']
result=[]
for word in lst:
  new_word=""
  for i in range(len(word)):
    if i>0 and word[i].isupper():
      new_word+=" "
    new_word+=word[i]
  result.append(new_word)
  print(result)
# Out:
# ['M L Is']
# ['M L Is', 'best For']
# ['M L Is', 'best For', 'data Scientist']

# %% [markdown]
# ### `Problem 11:` Write a program that can perform union operation on 2 lists
#
# **Example:**
#
# Input:
#
# ```bash
# [1,2,3,4,5,1]
# [2,3,5,7,8]
# ```
#
# Output:
# ```bash
# [1,2,3,4,5,7,8]
# ```

# %%
set_a=set([1,2,3,4,5,1])
set_b=set([2,3,5,7,8])
result=set_a.union(set_b)
print(list(result))
# Out:
# [1, 2, 3, 4, 5, 7, 8]

# %% [markdown]
# ### `Problem 12:` Write a program that can find the max number of each row of a matrix
#
# **Example:**
#
# Input:
#
# ```bash
# [[1,2,3],[4,5,6],[7,8,9]]
# ```
#
# Output:
# ```bash
# [3,6,9]
# ```

# %%
# def row_max(mat):
#   res=[]
#   for row in mat:
#     result.append(max(row))
#   return res
# mat=[[1,2,3],[4,5,6],[7,8,9]]
# print(row_max(mat))
matrix = [[1,2,3],[4,5,6],[7,8,9]]
result = [max(row) for row in matrix]
print(result)
# Out:
# [3, 6, 9]

# %% [markdown]
# ### `Problem 13:` Write a list comprehension to print the following matrix
#
# [[0, 1, 2], [3, 4, 5], [6, 7, 8]]

# %%
res=[[i*3+j for j in range(3)] for i in range(3)]
print(res)
# Out:
# [[0, 1, 2], [3, 4, 5], [6, 7, 8]]

# %% [markdown]
# ### `Problem 14:` Write a list comprehension that can transpose a given matrix
#
# matrix = [<br>
#   [1,2,3],<br>
#           [4,5,6],<br>
#           [7,8,9]<br>]<br>
#
# [1, 4, 7]<br>
# [2, 5, 8]<br>
# [3, 6, 9]<br>

# %%
matrix = [
[1,2,3],
[4,5,6],
[7,8,9]
]
transpose = [[row[i] for row in matrix] for i in range(len(matrix[0]))]
print(transpose)
# Out:
# [[1, 4, 7], [2, 5, 8], [3, 6, 9]]

# %% [markdown]
# ### `Problem 15:` Write a list comprehension that can flatten a nested list
#
# Input<br>
# matrix = [<br>
#   [1,2,3],<br>
#           [4,5,6],<br>
#           [7,8,9]<br>]<br>
#
# Output:<br>
# [1, 2, 3, 4, 5, 6, 7, 8, 9]

# %%
matrix = [
[1,2,3],
[4,5,6],
[7,8,9]
]
flatten=[num for row in matrix for num in row]
print(flatten)
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8, 9]
