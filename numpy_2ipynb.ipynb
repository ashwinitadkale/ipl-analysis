# %% [markdown]
# <a href="https://colab.research.google.com/github/ashwinitadkale/ipl-analysis/blob/main/numpy_2ipynb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

# %% [markdown]
# ###`Q-1:` Find the nearest element in the array to a given integer.
# ```
# Ex:-
# a=23 and array - [10 17 24 31 38 45 52 59].
# Nearest element is 24
# ```
# Hint: Read about this function `argmin()`

# %%
arr=np.array([10,17,24,31,38,45,52,59])
a=23
nearest=arr[np.abs(arr-a).argmin()]
print(nearest)
# Out:
# 24

# %% [markdown]
# ###`Q-2:` Replace multiples of 3 or 5 as 0 in the given array.
# ```
# arr=[1 2 3 4 5 6 7 9]
#
# result-> [1 2 0 4 0 0 7 0]
# ```

# %%
arr = np.array([1,2,3,4,5,6,7,9])
arr[(arr%3==0) | (arr%5==0)]=0
print(arr)
# Out:
# [1 2 0 4 0 0 7 0]

# %% [markdown]
# ###`Q-3:` Use Fancy Indexing.
# 1. Double the array elements at  given indexes
# ```
# arr = np.arrange(10)
# indexes = [0,3,4,9]
# ```
# Result -> `[ 0  1  2  6  8  5  6  7  8 18]`
#
# 2. Using a given array make a different array as in below example
# ```
# array = [1,2,3]
# result array -> [1 1 1 2 2 2 3 3 3]
# ```
# * Internal-repetion should be as length of the array.
#
# Hint:
# ```
# if a is an array
# a = [2,4]
# a[[1,1,0,1]] will result in-> [4 4 2 4]
# ```

# %%
arr=np.arange(10)
indexes=[0,3,4,9]
arr[indexes]*=2
print(arr)
# Out:
# [ 0  1  2  6  8  5  6  7  8 18]

# %%
array=np.array([1,2,3])
res=np.repeat(array,len(array))
print(res)
# Out:
# [1 1 1 2 2 2 3 3 3]

# %% [markdown]
# ###`Q-4:` Your are given an array which is havig some nan value. You job is to fill those nan values with most common element in the array.
# ```
# arr=np.array([[1,2,np.nan],[4,2,6],[np.nan,np.nan,5]])
#
# ```

# %%
arr=np.array([[1,2,np.nan],[4,2,6],[np.nan,np.nan,5]])
print(arr)
vals=arr[~np.isnan(arr)]
mode=np.bincount(vals.astype(int)).argmax()
arr[np.isnan(arr)]=mode #Boolean indexing
print(arr)
# Out:
# [[ 1.  2. nan]
#  [ 4.  2.  6.]
#  [nan nan  5.]]
# [[1. 2. 2.]
#  [4. 2. 6.]
#  [2. 2. 5.]]

# %% [markdown]
# ### `Q-5:` Write a NumPy program
#
# - to find the missing data in a given array. Return a boolean matrix.
# - also try to fill those missing values with 0. For that, you can use `np.nan_to_num(a)`

# %%
import numpy as np

arr1=np.array([[3, 2, np.nan, 1],
          [10, 12, 10, 9],
          [5, np.nan, 1, np.nan]])

# %%
missing=np.isnan(arr1)
print(missing)
# Out:
# [[False False  True False]
#  [False False False False]
#  [False  True False  True]]

# %%
# numpy.nan_to_num(x, copy=True, nan=0.0, posinf=None, neginf=None)
filled=np.nan_to_num(arr1) #By default replaces NaN with 0
print(filled)
# Out:
# [[ 3.  2.  0.  1.]
#  [10. 12. 10.  9.]
#  [ 5.  0.  1.  0.]]

# %% [markdown]
# ###`Q-6:` Given two arrays, X and Y, construct the Cauchy matrix C.
# `Cij =1/(xi - yj)`
#
# http://en.wikipedia.org/wiki/Cauchy_matrix
# ```
# x = numpy.array([1,2,3,4]).reshape((-1, 1)
# y = numpy.array([5,6,7])
# ```

# %%
x = np.array([1,2,3,4]).reshape((-1,1))
y = np.array([5,6,7])

C = 1 / (x - y)
print(C)
# Out:
# [[-0.25       -0.2        -0.16666667]
#  [-0.33333333 -0.25       -0.2       ]
#  [-0.5        -0.33333333 -0.25      ]
#  [-1.         -0.5        -0.33333333]]

# %% [markdown]
# ###`Q-7:` Plot this below equation.
#
# $$\large y = \frac{e^x - e^{-x}}{e^x + e^{-x}}$$

# %%
import matplotlib.pyplot as plt
x = np.linspace(-5,5,100)

y = (np.exp(x) - np.exp(-x)) / (np.exp(x) + np.exp(-x))

plt.plot(x,y)
plt.title("tanh function")
plt.grid()
plt.show()

# %% [markdown]
# ### `Q-8:` Plot the below equation.
#
# $$\large y = \sqrt{36 - (x - 4)^2} + 2$$
#
# The range of x should be between -2 to 10. $x ∈ [-2, 10]$

# %%
x=np.linspace(-2,10,100)
y=np.sqrt(36-(x-4)**2)+2
plt.plot(x,y)
plt.title("Curve")
plt.grid()
plt.show()

# %% [markdown]
# ### `Q-9:` Write a program implement Boradcasting Rule to check if two array can be added or not.
# Given tuples of shapes.
# ```
# shape of a- (3,2,2)
# shape of b- (2,2)
#
# check_broadcast(a, b) -> return Boolean (True if can broadcasted, False other wise.)
# ```

# %%
def check_broadcast(shape1, shape2):
    for a, b in zip(shape1[::-1], shape2[::-1]):
        if a != b and a != 1 and b != 1:
            return False
    return True

# Example
print(check_broadcast((3,2,2), (2,2)))  # True
# Out:
# True
